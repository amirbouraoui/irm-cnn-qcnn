# %% [markdown]
# # MNIST Exemple from https://pennylane.ai/qml/demos/tutorial_quanvolution

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
import seaborn
from tensorflow import keras
import matplotlib.pyplot as plt
import os

# %%
n_epochs = 30   # Number of optimization epochs
n_layers = 1    # Number of random layers
n_train = 50    # Size of the train dataset
n_test = 30     # Size of the test dataset
SAVE_PATH = "./_static/quanvolution/"

# Create folder if it does not exist
if not os.path.exists(SAVE_PATH):
    os.makedirs(SAVE_PATH)


  # Data saving folder
PREPROCESS = True           # If False, skip quantum processing and load data from SAVE_PATH
np.random.seed(0)           # Seed for NumPy random number generator
tf.random.set_seed(0)       # Seed for TensorFlow random number generator

# %%
mnist_dataset = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist_dataset.load_data()

# Reduce dataset size
train_images = train_images[:n_train]
train_labels = train_labels[:n_train]
test_images = test_images[:n_test]
test_labels = test_labels[:n_test]

# Normalize pixel values within 0 and 1
train_images = train_images / 255
test_images = test_images / 255

# Add extra dimension for convolution channels
train_images = np.array(train_images[..., tf.newaxis], requires_grad=False)
test_images = np.array(test_images[..., tf.newaxis], requires_grad=False)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 2))
for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.imshow(train_images[i])
    plt.title(str(train_labels[i]))
    plt.axis("off")
plt.tight_layout()
plt.show()

# %%
dev = qml.device("default.qubit", wires=4)
# Random circuit parameters
rand_params = np.random.uniform(high=2 * np.pi, size=(n_layers, 4))

@qml.qnode(dev)
def circuit(phi):
    # Encoding of 4 classical input values
    for j in range(4):
        qml.RY(np.pi * phi[j], wires=j)

    # Random quantum circuit
    RandomLayers(rand_params, wires=list(range(4)))

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# %%
def quanv(image):
    """Convolves the input image with many applications of the same quantum circuit."""
    out = np.zeros((14, 14, 4))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 28, 2):
        for k in range(0, 28, 2):
            # Process a squared 2x2 region of the image with a quantum circuit
            q_results = circuit(
                [
                    image[j, k, 0],
                    image[j, k + 1, 0],
                    image[j + 1, k, 0],
                    image[j + 1, k + 1, 0]
                ]
            )
            # Assign expectation values to different channels of the output pixel (j/2, k/2)
            for c in range(4):
                out[j // 2, k // 2, c] = q_results[c]
    return out

# %%
if PREPROCESS == True:
    q_train_images = []
    print("Quantum pre-processing of train images:")
    for idx, img in enumerate(train_images):
        print("{}/{}        ".format(idx + 1, n_train), end="\r")
        q_train_images.append(quanv(img))
    q_train_images = np.asarray(q_train_images)

    q_test_images = []
    print("\nQuantum pre-processing of test images:")
    for idx, img in enumerate(test_images):
        print("{}/{}        ".format(idx + 1, n_test), end="\r")
        q_test_images.append(quanv(img))
    q_test_images = np.asarray(q_test_images)
    
    # Save pre-processed images
    np.save(SAVE_PATH + "q_train_images.npy", q_train_images)
    np.save(SAVE_PATH + "q_test_images.npy", q_test_images)


# Load pre-processed images
q_train_images = np.load(SAVE_PATH + "q_train_images.npy")
q_test_images = np.load(SAVE_PATH + "q_test_images.npy")
# Out:
# Quantum pre-processing of train images:
# 50/50
# Quantum pre-processing of test images:
# 30/30

# %%
n_samples = 4
n_channels = 4
fig, axes = plt.subplots(1 + n_channels, n_samples, figsize=(10, 10))
for k in range(n_samples):
    axes[0, 0].set_ylabel("Input")
    if k != 0:
        axes[0, k].yaxis.set_visible(False)
    axes[0, k].imshow(train_images[k, :, :, 0], cmap="gray")

    # Plot all output channels
    for c in range(n_channels):
        axes[c + 1, 0].set_ylabel("Output [ch. {}]".format(c))
        if k != 0:
            axes[c, k].yaxis.set_visible(False)
        axes[c + 1, k].imshow(q_train_images[k, :, :, c], cmap="gray")

plt.tight_layout()
plt.show()

# %%
def MyModel():
    """Initializes and returns a custom Keras model
    which is ready to be trained."""
    model = keras.models.Sequential([
        keras.layers.Flatten(),
        keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

# %%
q_model = MyModel()

q_history = q_model.fit(
    q_train_images,
    train_labels,
    validation_data=(q_test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 13/13 - 0s - loss: 2.8082 - accuracy: 0.1000 - val_loss: 2.4627 - val_accuracy: 0.2333 - 402ms/epoch - 31ms/step
# Epoch 2/30
# 13/13 - 0s - loss: 2.0315 - accuracy: 0.2800 - val_loss: 2.2369 - val_accuracy: 0.1333 - 102ms/epoch - 8ms/step
# Epoch 3/30
# 13/13 - 0s - loss: 1.7129 - accuracy: 0.5000 - val_loss: 2.1065 - val_accuracy: 0.2333 - 102ms/epoch - 8ms/step
# Epoch 4/30
# 13/13 - 0s - loss: 1.3569 - accuracy: 0.5800 - val_loss: 1.9226 - val_accuracy: 0.3333 - 99ms/epoch - 8ms/step
# Epoch 5/30
# 13/13 - 0s - loss: 1.1477 - accuracy: 0.7200 - val_loss: 1.7713 - val_accuracy: 0.4333 - 93ms/epoch - 7ms/step
# Epoch 6/30
# 13/13 - 0s - loss: 0.9878 - accuracy: 0.8200 - val_loss: 1.7495 - val_accuracy: 0.3667 - 99ms/epoch - 8ms/step
# Epoch 7/30
# 13/13 - 0s - loss: 0.7986 - accuracy: 0.8800 - val_loss: 1.6666 - val_accuracy: 0.4000 - 90ms/epoch - 7ms/step
# Epoch 8/30
# 13/13 - 0s - loss: 0.6632 - accuracy: 0.9600 - val_loss: 1.5597 - val_accuracy: 0.5000 - 87ms/epoch - 7ms/step
# Epoch 9/30
# 13/13 - 0s - loss: 0.5758 - accuracy: 0.9800 - val_loss: 1.4775 - val_accuracy: 0.5333 - 86ms/epoch - 7ms/step
# Epoch 10/30
# 13/13 - 0s - loss: 0.4762 - accuracy: 1.0000 - val_loss: 1.5094 - val_accuracy: 0.5000 - 86ms/epoch - 7ms/step
# Epoch 11/30
# 13/13 - 0s - loss: 0.4395 - accuracy: 1.0000 - val_loss: 1.4469 - val_accuracy: 0.5000 - 86ms/epoch - 7ms/step
# Epoch 12/30
# 13/13 - 0s - loss: 0.3854 - accuracy: 1.0000 - val_loss: 1.4416 - val_accuracy: 0.5667 - 85ms/epoch - 7ms/step
# Epoch 13/30
# 13/13 - 0s - loss: 0.3420 - accuracy: 1.0000 - val_loss: 1.3693 - val_accuracy: 0.6333 - 89ms/epoch - 7ms/step
# Epoch 14/30
# 13/13 - 0s - loss: 0.3160 - accuracy: 1.0000 - val_loss: 1.3589 - val_accuracy: 0.5667 - 88ms/epoch - 7ms/step
# Epoch 15/30
# 13/13 - 0s - loss: 0.2648 - accuracy: 1.0000 - val_loss: 1.3167 - val_accuracy: 0.6333 - 86ms/epoch - 7ms/step
# Epoch 16/30
# 13/13 - 0s - loss: 0.2351 - accuracy: 1.0000 - val_loss: 1.3320 - val_accuracy: 0.6333 - 85ms/epoch - 7ms/step
# Epoch 17/30
# 13/13 - 0s - loss: 0.2185 - accuracy: 1.0000 - val_loss: 1.2959 - val_accuracy: 0.6000 - 85ms/epoch - 7ms/step
# Epoch 18/30
# 13/13 - 0s - loss: 0.1954 - accuracy: 1.0000 - val_loss: 1.2797 - val_accuracy: 0.6333 - 83ms/epoch - 6ms/step
# Epoch 19/30
# 13/13 - 0s - loss: 0.1775 - accuracy: 1.0000 - val_loss: 1.2875 - val_accuracy: 0.6333 - 84ms/epoch - 6ms/step
# Epoch 20/30
# 13/13 - 0s - loss: 0.1655 - accuracy: 1.0000 - val_loss: 1.2547 - val_accuracy: 0.6333 - 142ms/epoch - 11ms/step
# Epoch 21/30
# 13/13 - 0s - loss: 0.1516 - accuracy: 1.0000 - val_loss: 1.2750 - val_accuracy: 0.6333 - 104ms/epoch - 8ms/step
# Epoch 22/30
# 13/13 - 0s - loss: 0.1376 - accuracy: 1.0000 - val_loss: 1.2332 - val_accuracy: 0.6333 - 90ms/epoch - 7ms/step
# Epoch 23/30
# 13/13 - 0s - loss: 0.1296 - accuracy: 1.0000 - val_loss: 1.2166 - val_accuracy: 0.6333 - 94ms/epoch - 7ms/step
# Epoch 24/30
# 13/13 - 0s - loss: 0.1210 - accuracy: 1.0000 - val_loss: 1.2168 - val_accuracy: 0.6333 - 104ms/epoch - 8ms/step
# Epoch 25/30
# 13/13 - 0s - loss: 0.1158 - accuracy: 1.0000 - val_loss: 1.2097 - val_accuracy: 0.6333 - 101ms/epoch - 8ms/step
# Epoch 26/30
# 13/13 - 0s - loss: 0.1051 - accuracy: 1.0000 - val_loss: 1.2082 - val_accuracy: 0.6333 - 105ms/epoch - 8ms/step
# Epoch 27/30
# 13/13 - 0s - loss: 0.0999 - accuracy: 1.0000 - val_loss: 1.1887 - val_accuracy: 0.6333 - 111ms/epoch - 9ms/step
# Epoch 28/30
# 13/13 - 0s - loss: 0.0978 - accuracy: 1.0000 - val_loss: 1.1883 - val_accuracy: 0.6333 - 94ms/epoch - 7ms/step
# Epoch 29/30
# 13/13 - 0s - loss: 0.0900 - accuracy: 1.0000 - val_loss: 1.2094 - val_accuracy: 0.6333 - 91ms/epoch - 7ms/step
# Epoch 30/30
# 13/13 - 0s - loss: 0.0831 - accuracy: 1.0000 - val_loss: 1.1861 - val_accuracy: 0.6333 - 92ms/epoch - 7ms/step

# %%
c_model = MyModel()

c_history = c_model.fit(
    train_images,
    train_labels,
    validation_data=(test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 13/13 - 0s - loss: 2.3382 - accuracy: 0.1200 - val_loss: 2.3356 - val_accuracy: 0.1667 - 352ms/epoch - 27ms/step
# Epoch 2/30
# 13/13 - 0s - loss: 1.9698 - accuracy: 0.3400 - val_loss: 2.1593 - val_accuracy: 0.3000 - 96ms/epoch - 7ms/step
# Epoch 3/30
# 13/13 - 0s - loss: 1.6815 - accuracy: 0.5800 - val_loss: 1.9998 - val_accuracy: 0.4333 - 90ms/epoch - 7ms/step
# Epoch 4/30
# 13/13 - 0s - loss: 1.4441 - accuracy: 0.8200 - val_loss: 1.8521 - val_accuracy: 0.5000 - 98ms/epoch - 8ms/step
# Epoch 5/30
# 13/13 - 0s - loss: 1.2377 - accuracy: 0.9200 - val_loss: 1.7185 - val_accuracy: 0.6000 - 89ms/epoch - 7ms/step
# Epoch 6/30
# 13/13 - 0s - loss: 1.0736 - accuracy: 0.9200 - val_loss: 1.6206 - val_accuracy: 0.5667 - 91ms/epoch - 7ms/step
# Epoch 7/30
# 13/13 - 0s - loss: 0.9345 - accuracy: 0.9200 - val_loss: 1.5426 - val_accuracy: 0.5667 - 115ms/epoch - 9ms/step
# Epoch 8/30
# 13/13 - 0s - loss: 0.8180 - accuracy: 0.9600 - val_loss: 1.4682 - val_accuracy: 0.5667 - 96ms/epoch - 7ms/step
# Epoch 9/30
# 13/13 - 0s - loss: 0.7230 - accuracy: 0.9600 - val_loss: 1.4089 - val_accuracy: 0.6000 - 96ms/epoch - 7ms/step
# Epoch 10/30
# 13/13 - 0s - loss: 0.6419 - accuracy: 0.9600 - val_loss: 1.3654 - val_accuracy: 0.6000 - 95ms/epoch - 7ms/step
# Epoch 11/30
# 13/13 - 0s - loss: 0.5788 - accuracy: 0.9600 - val_loss: 1.3178 - val_accuracy: 0.6000 - 97ms/epoch - 7ms/step
# Epoch 12/30
# 13/13 - 0s - loss: 0.5203 - accuracy: 0.9800 - val_loss: 1.3033 - val_accuracy: 0.5667 - 96ms/epoch - 7ms/step
# Epoch 13/30
# 13/13 - 0s - loss: 0.4715 - accuracy: 0.9800 - val_loss: 1.2686 - val_accuracy: 0.6000 - 106ms/epoch - 8ms/step
# Epoch 14/30
# 13/13 - 0s - loss: 0.4259 - accuracy: 1.0000 - val_loss: 1.2297 - val_accuracy: 0.6000 - 90ms/epoch - 7ms/step
# Epoch 15/30
# 13/13 - 0s - loss: 0.3864 - accuracy: 1.0000 - val_loss: 1.2041 - val_accuracy: 0.6333 - 89ms/epoch - 7ms/step
# Epoch 16/30
# 13/13 - 0s - loss: 0.3538 - accuracy: 1.0000 - val_loss: 1.1868 - val_accuracy: 0.6333 - 85ms/epoch - 7ms/step
# Epoch 17/30
# 13/13 - 0s - loss: 0.3261 - accuracy: 1.0000 - val_loss: 1.1695 - val_accuracy: 0.6333 - 85ms/epoch - 7ms/step
# Epoch 18/30
# 13/13 - 0s - loss: 0.3010 - accuracy: 1.0000 - val_loss: 1.1464 - val_accuracy: 0.6000 - 84ms/epoch - 6ms/step
# Epoch 19/30
# 13/13 - 0s - loss: 0.2756 - accuracy: 1.0000 - val_loss: 1.1379 - val_accuracy: 0.6333 - 90ms/epoch - 7ms/step
# Epoch 20/30
# 13/13 - 0s - loss: 0.2565 - accuracy: 1.0000 - val_loss: 1.1179 - val_accuracy: 0.7000 - 103ms/epoch - 8ms/step
# Epoch 21/30
# 13/13 - 0s - loss: 0.2382 - accuracy: 1.0000 - val_loss: 1.1141 - val_accuracy: 0.6667 - 100ms/epoch - 8ms/step
# Epoch 22/30
# 13/13 - 0s - loss: 0.2214 - accuracy: 1.0000 - val_loss: 1.1007 - val_accuracy: 0.7000 - 99ms/epoch - 8ms/step
# Epoch 23/30
# 13/13 - 0s - loss: 0.2064 - accuracy: 1.0000 - val_loss: 1.0905 - val_accuracy: 0.7000 - 99ms/epoch - 8ms/step
# Epoch 24/30
# 13/13 - 0s - loss: 0.1932 - accuracy: 1.0000 - val_loss: 1.0809 - val_accuracy: 0.7000 - 97ms/epoch - 7ms/step
# Epoch 25/30
# 13/13 - 0s - loss: 0.1826 - accuracy: 1.0000 - val_loss: 1.0743 - val_accuracy: 0.7000 - 99ms/epoch - 8ms/step
# Epoch 26/30
# 13/13 - 0s - loss: 0.1705 - accuracy: 1.0000 - val_loss: 1.0670 - val_accuracy: 0.7000 - 91ms/epoch - 7ms/step
# Epoch 27/30
# 13/13 - 0s - loss: 0.1612 - accuracy: 1.0000 - val_loss: 1.0562 - val_accuracy: 0.7000 - 88ms/epoch - 7ms/step
# Epoch 28/30
# 13/13 - 0s - loss: 0.1528 - accuracy: 1.0000 - val_loss: 1.0499 - val_accuracy: 0.7000 - 87ms/epoch - 7ms/step
# Epoch 29/30
# 13/13 - 0s - loss: 0.1437 - accuracy: 1.0000 - val_loss: 1.0481 - val_accuracy: 0.7000 - 112ms/epoch - 9ms/step
# Epoch 30/30
# 13/13 - 0s - loss: 0.1356 - accuracy: 1.0000 - val_loss: 1.0437 - val_accuracy: 0.7000 - 101ms/epoch - 8ms/step

# %%
import matplotlib.pyplot as plt
import sys

plt.style.use("seaborn-v0_8")

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 9))

ax1.plot(q_history.history["val_accuracy"], "-ob", label="With quantum layer")
ax1.plot(c_history.history["val_accuracy"], "-og", label="Without quantum layer")
ax1.set_ylabel("Accuracy")
ax1.set_ylim([0, 1])
ax1.set_xlabel("Epoch")
ax1.legend()

ax2.plot(q_history.history["val_loss"], "-ob", label="With quantum layer")
ax2.plot(c_history.history["val_loss"], "-og", label="Without quantum layer")
ax2.set_ylabel("Loss")
ax2.set_ylim(top=2.5)
ax2.set_xlabel("Epoch")
ax2.legend()
plt.tight_layout()
plt.show()
